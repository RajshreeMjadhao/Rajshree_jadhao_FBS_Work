# %% [markdown]
# ## 7 Feb 2026

# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/Iris.csv')

# %%
type(data) ## It will return the type of datatype is a dataframe.
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns ## It will return the columns name is a array format.
# Out:
# Index(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width',
#        'Species'],
#       dtype='object')

# %%
data.shape## It will return the numbers of row and columns present in a data.
# Out:
# (150, 5)

# %%
data.head()## It will return the start 5 rows data.
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
data.head(10) ## It will return number of record we want in categorical format.
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
data.tail() ## It will return the ending 5 rows data.
# data.tail(7) ->> and this one is return how many data we want.
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
# data['Species'].unique() ## Reeturn the unique value in array format not duplicate one.
data['Species'].nunique() ## Return in numerical format unique values.
# Out:
# 3

# %%
data['Species'].value_counts() ## return the number of species present in series.
# Out:
# Species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
data.isna().sum() ## It will check the null value present in data or not if yes then write in numerical format or not then show 0.
# Out:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal_Width     0
# Species         0
# dtype: int64

# %%
data = pd.read_csv('datasets/cars93.csv')

# %%
data.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
data.tail()
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 88   Volkswagen  Eurovan      Van   19.7        17  Driver & Passenger
# 89   Volkswagen   Passat  Compact   20.0        21  Driver & Passenger
# 90   Volkswagen  Corrado   Sporty   23.3        18  Driver & Passenger
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 88         109           7            34.0           NaN
# 89         134           5            31.5          14.0
# 90         178           4            26.0          15.0
# 91         114           5            29.5          14.0
# 92         168           5            30.0          15.0

# %%
data.shape
# Out:
# (93, 10)

# %%
# data['Manufacturer'].unique()
data['Manufacturer'].nunique() ## Data Analysis is a case sensitive languang.
# Out:
# 32

# %%
data['Type'].value_counts()
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
data.isna().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           14
# Horsepower         0
# Passengers         0
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
data.info() #Print a concise summary of a DataFrame.

# This method prints information about a DataFrame including
# the index dtype and columns, non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    93 non-null     object
#  1   Model           93 non-null     object
#  2   Type            93 non-null     object
#  3   Price           93 non-null     float64
#  4   MPG.city        93 non-null     int64
#  5   AirBags         79 non-null     object
#  6   Horsepower      93 non-null     int64
#  7   Passengers      93 non-null     int64
#  8   Rear.seat.room  91 non-null     float64
#  9   Luggage.room    82 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 7.4+ KB

# %%
data[data['Rear.seat.room'].isna()==True]  ## We can see missing value using isna()==true of a rear.seta.room.
# Out:
#    Manufacturer     Model    Type  Price  MPG.city      AirBags  Horsepower  \
# 18    Chevrolet  Corvette  Sporty   38.0        17  Driver only         300
# 56        Mazda      RX-7  Sporty   32.5        17  Driver only         255
#
#     Passengers  Rear.seat.room  Luggage.room
# 18           2             NaN           NaN
# 56           2             NaN           NaN

# %%
# data.drop([10,56]) #->> Do not use this one will out filling others values is will drop rows and decrease the data.
#  data1 =data.dropna() # we have to store in different variables.

# %%
data[data['AirBags'].isna()==True] ## Return null records in airbags.
# Out:
#    Manufacturer    Model     Type  Price  MPG.city AirBags  Horsepower  \
# 16    Chevrolet    Astro      Van   16.6        15     NaN         165
# 32         Ford    Tempo  Compact   11.3        22     NaN          96
# 46      Hyundai   Sonata  Midsize   13.9        20     NaN         128
# 53        Mazda  Protege    Small   11.6        28     NaN         103
# 61   Mitsubishi   Mirage    Small   10.3        29     NaN          92
# 65       Nissan    Quest      Van   19.1        17     NaN         151
# 67   Oldsmobile  Achieva  Compact   13.5        24     NaN         155
# 71     Plymouth    Laser   Sporty   14.4        23     NaN          92
# 72      Pontiac   LeMans    Small    9.0        31     NaN          74
# 73      Pontiac  Sunbird  Compact   11.1        23     NaN         110
# 79       Subaru    Justy    Small    8.4        33     NaN          73
# 80       Subaru   Loyale    Small   10.9        25     NaN          90
# ...

# %%
data['AirBags'].unique()## Return the unique values.
# Out:
# array(['Driver only', 'Driver & Passenger', nan], dtype=object)

# %%
result = data['AirBags'].mode() ## Return the value that occurences multiple number of time.

# %%
result
# Out:
# 0    Driver only
# Name: AirBags, dtype: object

# %%
# data.loc[data['AirBags'].isna()==True,'AirBags'] = 'Driver only'  #-->> Fill the null in airbags to driver only in data.
data['AirBags']=data['AirBags'].fillna(result[0])

# %%
# data.isna().sum()

# %%
# data.head()

# %%
avg = data['Luggage.room'].mean()

# %%
avg ## Average of a luggage room.
# Out:
# np.float64(13.890243902439025)

# %%
data['Luggage.room'].fillna(avg,inplace = True) ## Fill the null value using avg in luggage room.
# Out:
# C:\Users\91814\AppData\Local\Temp\ipykernel_16804\1407083871.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Luggage.room'].fillna(avg,inplace = True) ## Fill the null value using avg in luggage room.

# %%
# data.isna().sum()

# %%
data.shape
# Out:
# (93, 10)

# %%
data1 = data1 =data.dropna() ## We drop the null values and store in different variable [data1] -->> Dropna return the values do not chnage the original data so that's why we have to store in data1.

# %%
data1.isna().sum()
# Out:
# Manufacturer      0
# Model             0
# Type              0
# Price             0
# MPG.city          0
# AirBags           0
# Horsepower        0
# Passengers        0
# Rear.seat.room    0
# Luggage.room      0
# dtype: int64

# %%
data1.shape
# Out:
# (91, 10)
