# %%
a = 30

# %%
b = 10

# %%
c = a - b

# %%
c
# Out:
# 20

# %%
print(c)
# Out:
# 20

# %%
a = 3

# %%
b = 4

# %%
c = a ** b

# %%
c
# Out:
# 81

# %%
c = a*a*a*a

# %%
c
# Out:
# 81

# %%
res = 1
for i in range(b):
    res = res * a
res
# Out:
# 81

# %%
import numpy as np

# %%
arr1 = np.array([2,3,4,5,6])
arr1
# Out:
# array([2, 3, 4, 5, 6])

# %%
arr2 = np.array([7,5,4,3,2])
arr2
# Out:
# array([7, 5, 4, 3, 2])

# %%
# In a array if we perform the (+) operator they will in execute but in the list it will give the concatination

# %%
# Array is a homogeneous data type && List is a heterogeneous data type

# %%
# Array support vectorization && List Does not support vectorization

# %%
arr3 = arr1 + arr2
arr3
# Out:
# array([9, 8, 8, 8, 8])

# %%
arr1 = np.array([1, 'FBS', 56.09])
arr1
# Out:
# array(['1', 'FBS', '56.09'], dtype='<U32')

# %%
## dtype = <U32 -> Is a unified text data type 
## In a array heterogeneous not work if we write then the output execute in a string format

# %%
arr2 = np.array([12,56,90.3])
arr2
# Out:
# array([12. , 56. , 90.3])

# %%
## In this output the 12. (.) is a like 0.

# %%
arr1.dtype
# Out:
# dtype('<U32')

# %%
arr2.dtype
# Out:
# dtype('float64')

# %%
# In a after float is a bit(64)

# %%
arr3 = np.array([1,2,3])
arr3.dtype # data type of a element in array
# Out:
# dtype('int64')

# %%
arr1.size ## Size of a array
# Out:
# 3

# %%
arr1.shape ## This will give the shape to the element
# Out:
# (3,)

# %%
arr1.ndim ## Number of dimentions
# Out:
# 1

# %%
arr = np.array([24,56,32])
result = arr > 25

# %%
result ## It will give also the output of a element.
# Out:
# array([False,  True,  True])

# %%
## List Time

# %%
# %%time
list1 = [x for x in range (1, 100001)]
list2 = [x for x in range (100001, 200001)]
list3 = []
for i in range(len (list1)):
    list3.append(list1[i]+list2[i])
# Out:
# CPU times: total: 78.1 ms
# Wall time: 49 ms

# %%
## Array time

# %%
# %%time
arr1 = np.array([ x for x in range (1,100001)])
arr2 = np.array([ x for x in range (100001, 200001)])
arr3 = arr1 + arr2
# Out:
# CPU times: total: 46.9 ms
# Wall time: 35.3 ms

# %%
## List Size

# %%
import sys
list = [34,45,56,67]
sys.getsizeof(list[0] * len(list))
# Out:
# 28

# %%
## Array Size

# %%
arr = np.array([34,45,56,67])
arr.itemsize * arr.size
# Out:
# 32
