# %%
import pandas as pd
import numpy as np

# %%
print(pd.__version__)
# Out:
# 2.3.1

# %%
# Series
# DataFrame

# %%
## Series : Collection of labelled Data
s1 =pd.Series([1,2,3,4],index = ['A','B','C','D'])
s1
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
s2 = pd.Series([10,20,30,40])
s2
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
arr1 = np.array([1,2,3,4])
arr1
# Out:
# array([1, 2, 3, 4])

# %%
intake = pd.Series([60,120,150,30], index =['civil','electrical','CS','IT'])
intake
# Out:
# civil          60
# electrical    120
# CS            150
# IT             30
# dtype: int64

# %%
players = pd.Series(['dhoni','kohli','rohit'])
players
# Out:
# 0    dhoni
# 1    kohli
# 2    rohit
# dtype: object

# %%
### Different ways to create series

# %%
arr1 = np.arange(21,31)
s1 = pd.Series(arr1)  # list,tuple,array
s1
# Out:
# 0    21
# 1    22
# 2    23
# 3    24
# 4    25
# 5    26
# 6    27
# 7    28
# 8    29
# 9    30
# dtype: int64

# %%
toppers = pd.Series({'math':85,'bio':70,'phy':80})
toppers
# Out:
# math    85
# bio     70
# phy     80
# dtype: int64

# %%
# Operation on Series

# %%
s1 = pd.Series(np.arange(21,26))
s2 = pd.Series(np.arange(16,21))

# %%
s1
# Out:
# 0    21
# 1    22
# 2    23
# 3    24
# 4    25
# dtype: int64

# %%
s2
# Out:
# 0    16
# 1    17
# 2    18
# 3    19
# 4    20
# dtype: int64

# %%
s3 = s1 + s2
s3
# Out:
# 0    37
# 1    39
# 2    41
# 3    43
# 4    45
# dtype: int64

# %%
s1 = pd.Series(np.arange(21,26),index =['A','B','C','D','E'])
s2 = pd.Series(np.arange(16,21), index =['D','E','F','G','H'])

# %%
s1
# Out:
# A    21
# B    22
# C    23
# D    24
# E    25
# dtype: int64

# %%
s2
# Out:
# D    16
# E    17
# F    18
# G    19
# H    20
# dtype: int64

# %%
s1 + s2 ## In a pandas the NaN means Null.
# Out:
# A     NaN
# B     NaN
# C     NaN
# D    40.0
# E    42.0
# F     NaN
# G     NaN
# H     NaN
# dtype: float64

# %%
s1 = pd.Series(np.random.randint(1,25,7))
s1
# Out:
# 0    16
# 1    10
# 2    14
# 3    17
# 4    23
# 5    11
# 6    18
# dtype: int32

# %%
s1.index=['x1','x2','x3','x4','x5','x6','x7']

# %%
s1['x4']
# Out:
# np.int32(17)

# %%
s1.iloc[2] ## Integer location >>It will give the position of a series
# Out:
# np.int32(14)

# %%
# Even numbers
s1[s1 %2 == 0]
# Out:
# x1    16
# x2    10
# x3    14
# x7    18
# dtype: int32

# %%
s1.min()
# Out:
# np.int32(10)

# %%
s1.max()
# Out:
# np.int32(23)

# %%
s1.sum()
# Out:
# np.int64(109)

# %%
s1.mean()
# Out:
# np.float64(15.571428571428571)

# %%
s1
# Out:
# x1    16
# x2    10
# x3    14
# x4    17
# x5    23
# x6    11
# x7    18
# dtype: int32

# %%
s1.mode() ## max occuring element in series
# Out:
# 0    10
# 1    11
# 2    14
# 3    16
# 4    17
# 5    18
# 6    23
# dtype: int32

# %%
s1
# Out:
# x1    16
# x2    10
# x3    14
# x4    17
# x5    23
# x6    11
# x7    18
# dtype: int32

# %%
# find out the elements greater than element at index x2 
s1[s1>s1['x2']]
# Out:
# x1    16
# x3    14
# x4    17
# x5    23
# x6    11
# x7    18
# dtype: int32

# %%
s1[s1<s1['x3']]  ##less than element also we can perform
# Out:
# x2    10
# x6    11
# dtype: int32
